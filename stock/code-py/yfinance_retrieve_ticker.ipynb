# %%
import sys
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
homedir='/Users/peter/projects/stock/data'
#stock_ticker=sys.argv[1]
stock_ticker='TSLA'

# %%
stock_obj=yf.Ticker(stock_ticker)
history=stock_obj.history(period="max")

# %%
print(stock_obj.shares)
# Out:
# None

# %%
expirs=stock_obj.options
k=stock_obj.option_chain(expirs[0])
calls=k.calls
oi=calls.openInterest
strikes=calls.strike
#plt.plot(expirs,oi)
plt.plot(strikes,oi)

# %%
plt.plot(expirs)

# %%
history.Open[:]
# Out:
# Date
# 2001-02-26    400.800302
# 2001-02-27    419.237088
# 2001-02-28    415.747245
# 2001-03-01    413.843954
# 2001-03-02    415.747373
#                  ...
# 2022-02-14    244.020004
# 2022-02-15    232.940002
# 2022-02-16    244.899994
# 2022-02-17    245.919998
# 2022-02-18    240.899994
# Name: Open, Length: 5281, dtype: float64
