# %%
import sys
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
homedir='/Users/peter/projects/stock/data'
#stock_ticker=sys.argv[1]
stock_ticker='OIH'

# %%
stock_obj=yf.Ticker(stock_ticker)
history=stock_obj.history(period="max")

# %%
expirs=stock_obj.options
k=stock_obj.option_chain(expirs[0])
calls=k.calls
oi=calls.openInterest
strikes=calls.strike
#plt.plot(expirs,oi)
plt.plot(strikes,oi)

# %%
plt.plot(expirs)

# %%
history.Open[:]
# Out:
# Date
# 2001-02-26    404.804410
# 2001-02-27    423.425101
# 2001-02-28    419.900286
# 2001-03-01    417.978316
# 2001-03-02    419.899986
#                  ...
# 2021-11-23    189.369995
# 2021-11-24    190.309998
# 2021-11-26    179.639999
# 2021-11-29    187.300003
# 2021-11-30    179.449997
# Name: Open, Length: 5225, dtype: float64
