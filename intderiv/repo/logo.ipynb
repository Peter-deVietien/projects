# %%
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

# %%
xlin=np.linspace(-10,10,1000)
ylin=np.linspace(-10,10,1000)

# %%
def f(x,y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

# %%
x,y=np.meshgrid(xlin,ylin)
z=f(x,y)

# %%
fig=plt.figure()
ax=plt.axes(projection='3d')
ax.contour3D(x,y,z,200,cmap='binary')
plt.show()

# %%
pngname='logo.png'
filepath='/Users/peter/projects/intderiv/media/' + pngname
print(filepath)
fig.savefig(filepath,dpi=2000)
# Out:
# /Users/peter/projects/intderiv/media/logo.png
